# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt

# creating a dataset with curvilinear relationship
x=10*np.random.normal(0,1,70)
y=10*(-x**2)+np.random.normal(-100,100,70)

#x = array([0, 1, 2, 3, 4, 5])
#y = array([0, 0.8, 0.9, 1, -0.8, -1])

# plotting dataset
plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

# %% [markdown]
# **How linear model fits on this data**

# %%
# Importing Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Training Model
lm=LinearRegression()
lm.fit(x.reshape(-1,1),y.reshape(-1,1))
y_pred=lm.predict(x.reshape(-1,1))

# plotting predictions
plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='r')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

print('RMSE for Linear Regression:',np.sqrt(mean_squared_error(y,y_pred)))
# Out:
# RMSE for Linear Regression: 1464.016621838082

# %% [markdown]
# **Polynomial Regression**
# ![image.png](attachment:image.png)

# %%
# importing libraries for polynomial transform
from sklearn.preprocessing import PolynomialFeatures

# for creating pipeline
from sklearn.pipeline import make_pipeline

# creating pipeline and fitting it on data
pipeline = make_pipeline(PolynomialFeatures(3), LinearRegression())
pipeline.fit(x.reshape(-1,1),y.reshape(-1,1))
poly_pred=pipeline.predict(x.reshape(-1,1))

#sorting predicted values with respect to predictor
sorted_zip = sorted(zip(x,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)

#plotting predictions
plt.figure(figsize=(10,6))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='r',label='Linear Regression')
plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.legend()
plt.show()

print('RMSE for Polynomial Regression=>',np.sqrt(mean_squared_error(y,poly_pred)))
# Out:
# RMSE for Polynomial Regression=> 2280.5955103432634
