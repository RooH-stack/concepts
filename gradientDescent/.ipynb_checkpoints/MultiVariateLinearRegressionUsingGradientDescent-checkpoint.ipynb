# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
# import the necessary libraries
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt

# %%
# import data and separate X and y variables
dt = genfromtxt('../data/dataMultivariateLRUsingGD.csv',delimiter=',')
print(dt[:5,:])
print()

X = dt[:,:3]
print(X[:5,:])
print()

y = dt[:,3]
print(y)
print()
# Out:
# [[0.         3.44       0.44       4.38754501]
#  [0.04040404 0.1349495  0.88848485 2.6796499 ]
#  [0.08080808 0.82989899 1.3369697  2.96848981]
#  [0.12121212 1.52484848 1.78545454 3.25406475]
#  [0.16161616 2.21979798 2.23393939 3.53637472]]
#
# [[0.         3.44       0.44      ]
#  [0.04040404 0.1349495  0.88848485]
#  [0.08080808 0.82989899 1.3369697 ]
#  [0.12121212 1.52484848 1.78545454]
#  [0.16161616 2.21979798 2.23393939]]
#
# [ 4.38754501  2.6796499   2.96848981  3.25406475  3.53637472  3.81541972
#   4.09119974  2.36371479  3.83296487  4.09894997  4.3616701   4.62112526
#   4.87731544  3.13024065  3.37990089  3.62629616  3.86942645  5.30929177
#   5.54589212  3.77922749  4.00929789  4.23610332  4.45964378  4.67991926
#   2.89692977  3.1106753   4.52115587  4.72837146  4.93232208  5.13300772
#   3.33042839  3.52458409  3.71547481  3.90310057  4.08746135  5.46855715
#   3.64638799  3.82095385  3.99225473  4.16029065  4.32506159  4.48656756
#   2.64480856  2.79978458  4.15149563  4.29994171  4.44512281  2.58703894
#   2.7256901   2.86107628  2.99319749  3.12205374  3.247645    2.56997129
#   2.68903261  2.80482896  2.91736034  3.02662674  3.13262817  1.23536462
#   1.3348361   1.43104261  2.72398415  2.81366071  2.9000723   0.98321892
#   1.06310057  1.13971724  1.21306894  1.28315566 -0.65002258  0.6135342
#   0.673826    0.73085284  0.7846147   0.83511159 -1.1176565  -1.07368956
#  -1.03298759 -0.99555059  0.23862143  0.26952848 -1.70282944 -1.67845234
#  -1.6573402  -1.63949305 -1.62491086 -1.61359365 -3.60554141 -2.40075414
#  -2.39923185 -2.40097453 -2.40598218 -4.4142548  -4.4257924  -4.44059497
#  -4.45866252 -4.47999504 -3.30459253 -5.33245499]

# %% [markdown]
# **multivariate linear regression using gradient descent**

# %%
# multivariate linear regression using gradient descent
def MultiVariateLinearRegressionUsingGradientDescent(X, y, alpha, epoch):
    m = X.shape[0]  # number of samples
    ones =np.ones((m,1))  
    X = np.concatenate((ones, X), axis=1) # Join two 2-D arrays along rows (axis=1) -- Now X with X0's is 1
    n = X.shape[1] # number of thetas -- 4
    Theta = np.ones(n) # paramater initalization -- In gradient descent we need to initialize the params
    h = np.dot(X, Theta) # compute hypothesis
    
    # Gradient descent algorithm
    cost = np.ones(epoch)
    for i in range (0, epoch):
        Theta[0] = Theta[0] - (alpha / X.shape[0]) * sum(h-y)
        for j in range(1, n):
            Theta[j]= Theta[j] - (alpha/ X.shape[0]) * sum((h-y) * X[:, j])
        h  = np.dot(X, Theta)
        cost[i] = 1/(2*m) * sum(np.square(h-y))  # Compute Cost
    return cost, Theta

# %%
# calculate theta and cost
cost, theta = MultiVariateLinearRegressionUsingGradientDescent(X, y, 0.1, 2000)
print(theta)
# Out:
# [ 5.31416716 -2.00371927  0.53256334 -0.26560186]

# %%
# checking out the loss or cost plot
plt.plot(cost)
plt.xlabel("Epoch (No. of iterations)")
plt.ylabel("Cost")
plt.show()
print("Lowest cost = " + str(np.min(cost)))
print("Cost after 2000 iterations = " + str(cost[-1]))
# Out:
# Lowest cost = 0.7384642415682937
# Cost after 2000 iterations = 0.7384642415682943

# %%
X_predict_1= np.array([1,2,0,4])
y_predict_1= np.dot(X_predict_1, theta)
print(y_predict_1)
# Out:
# 0.2443211716166045

# %%
#Predictions for the new values using the model
X_predict_1=np.array([1,1,1])
X_predict_2=np.array([2,0,4])
X_predict_3=np.array([3,2,1])

#Predictions
X_predict_1 = np.concatenate(([1], X_predict_1), axis = 0) # Adding one colum of one in the beggining
y_predict_1=np.dot(theta, X_predict_1)
print("Prediction for (1,1,1) = " + str(y_predict_1))

X_predict_2 = np.concatenate(([1], X_predict_2), axis = 0) # Adding one colum of one in the beggining
y_predict_2=np.dot(theta, X_predict_2)
print("Prediction for (2,0,4) = " + str(y_predict_2))

X_predict_3 = np.concatenate(([1], X_predict_3), axis = 0) # Adding one colum of one in the beggining
y_predict_3=np.dot(theta, X_predict_3)
print("Prediction for (3,2,1) = " + str(y_predict_3))
# Out:
# Prediction for (1,1,1) = 3.577409369212849
# Prediction for (2,0,4) = 0.2443211716166045
# Prediction for (3,2,1) = 0.10253417197052594

# %% [markdown]
# **Validating the model using Built-in Linear Regression Function**

# %%
from sklearn import linear_model # Importing linear model
lm = linear_model.LinearRegression() # Linear regression
lm.fit(X, y) # Fitting the data

# Printing the thetas (intercept and coefs)
print(lm.intercept_, lm.coef_)

#Predictions
X_predict_1=np.array([[1,1,1]])
X_predict_2=np.array([[2,0,4]])
X_predict_3=np.array([[3,2,1]])
print("Prediction for (1,1,1) = " + str(lm.predict(X_predict_1)))
print("Prediction for (2,0,4) = " + str(lm.predict(X_predict_2)))
print("Prediction for (3,2,1) = " + str(lm.predict(X_predict_3)))
# Out:
# 5.3141671724569814 [-2.00371927  0.53256334 -0.26560187]
# Prediction for (1,1,1) = [3.57740937]
# Prediction for (2,0,4) = [0.24432117]
# Prediction for (3,2,1) = [0.10253417]
